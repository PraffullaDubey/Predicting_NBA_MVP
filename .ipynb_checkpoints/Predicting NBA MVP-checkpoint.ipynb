# %% [markdown]
# # Import the required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import missingno as msno

# %% [markdown]
# # Read the Dataset

# %%
dfh = pd.read_csv('Historical_MVPdata.csv')
dfc = pd.read_csv('CurrentMVP.csv')

# %% [markdown]
# # Data Exploration

# %%
dfh.shape
# Out:
# (408, 27)

# %%
dfc.shape
# Out:
# (10, 25)

# %% [markdown]
# The historical_MPVdata.csv contains 408 rows and 27 columns whereas,
# the CurrentMVP.csv contains 10 rows and 25 columns.

# %%
dfh.head() #check the first 5 entries in the dataset
# Out:
#    Rank               Player  Age   Tm  Pts Won  Pts Max  Share     G  \
# 0     1  Kareem Abdul-Jabbar   32  LAL    147.0      221  0.665  82.0
# 1     2        Julius Erving   29  PHI     31.5      221  0.143  78.0
# 2     3        George Gervin   27  SAS     19.0      221  0.086  78.0
# 3     4           Larry Bird   23  BOS     15.0      221  0.068  82.0
# 4     5       Tiny Archibald   31  BOS      2.0      221  0.009  80.0
#
#    Team Wins  Overall Seed  ...    3P%    FT%    WS  WS/48  VORP  BPM  \
# 0       60.0             2  ...  0.000  0.765  14.8  0.227   6.8  6.7
# 1       59.0             3  ...  0.200  0.787  12.5  0.213   6.5  7.2
# 2       41.0            10  ...  0.314  0.852  10.6  0.173   3.1  2.2
# 3       61.0             1  ...  0.406  0.836  11.2  0.182   5.4  5.3
# 4       61.0             1  ...  0.222  0.830   8.9  0.148   1.5  0.0
#
#    G-Lockout  Wins-Lockout  WS-Lockout  VORP-Lockout
# 0        NaN           NaN         NaN           NaN
# 1        NaN           NaN         NaN           NaN
# 2        NaN           NaN         NaN           NaN
# 3        NaN           NaN         NaN           NaN
# 4        NaN           NaN         NaN           NaN
#
# [5 rows x 27 columns]

# %%
dfc.head() #check the first 5 entries in the dataset
# Out:
#    Rank                 Player  Age   Tm          G  Team Wins  Overall Seed  \
# 0     1           Nikola Jokić   26  DEN  82.000000  48.809524             8
# 1     2            Joel Embiid   27  PHI  59.116279  57.209302             1
# 2     3  Giannis Antetokounmpo   26  MIL  80.000000  54.000000             7
# 3     4           James Harden   31  BRK  70.558140  55.302326             3
# 4     5         Damian Lillard   30  POR  80.047619  48.809524             9
#
#      MP   PTS   TRB  ...    FT%         WS  WS/48       VORP   BPM  \
# 0  35.8  27.1  11.2  ...  0.866  18.938095  0.310  10.347619  11.9
# 1  32.6  29.9  11.5  ...  0.859  11.823256  0.294   5.148837   8.6
# 2  34.2  29.0  11.7  ...  0.679  14.200000  0.250  13.200000  11.5
# 3  37.9  25.3   8.0  ...  0.866  11.823256  0.211   5.720930   6.5
# 4  36.0  30.3   4.4  ...  0.940  13.080952  0.217   6.052381   6.3
#
#    G-Unadjusted  Wins-Unadjusted  WS-Unadjusted  VORP-Unadjusted  Total Games
# 0            42               25            9.7              5.3           42
# 1            31               30            6.2              2.7           43
# 2            40               27            7.1              6.6           41
# 3            37               29            6.2              3.0           43
# 4            41               25            6.7              3.1           42
#
# [5 rows x 25 columns]

# %%
dfh.describe()
# Out:
#              Rank         Age      Pts Won      Pts Max       Share  \
# count  408.000000  408.000000   408.000000   408.000000  408.000000
# mean     5.446078   27.299020   268.748529  1043.796569    0.254164
# std      2.834854    3.522312   324.014148   227.478261    0.292090
# min      1.000000   19.000000     1.000000   221.000000    0.002000
# 25%      3.000000   25.000000    30.750000   920.000000    0.029750
# 50%      5.000000   27.000000   106.000000  1130.000000    0.108500
# 75%      8.000000   30.000000   428.500000  1230.000000    0.404500
# max     10.000000   38.000000  1310.000000  1310.000000    1.000000
#
#                 G   Team Wins  Overall Seed         MP         PTS  ...  \
# count  408.000000  408.000000    408.000000  408.00000  408.000000  ...
# mean    76.610793   53.653289      6.078431   36.94951   23.764461  ...
# std      6.219986    7.468348      4.654524    2.54087    4.682918  ...
# min     44.000000   24.000000      1.000000   28.00000    6.900000  ...
# 25%     74.000000   49.000000      2.750000   35.37500   20.900000  ...
# 50%     79.000000   55.000000      5.000000   37.20000   23.900000  ...
# 75%     81.000000   58.098485      9.000000   38.60000   27.025000  ...
# max     82.000000   73.000000     24.000000   43.70000   37.100000  ...
#
#               3P%         FT%          WS       WS/48        VORP         BPM  \
# count  408.000000  408.000000  408.000000  408.000000  408.000000  408.000000
# mean     0.259233    0.778988   12.249833    0.206831    5.494054    5.650735
# std      0.136239    0.094596    2.930865    0.043229    2.032271    2.607653
# min      0.000000    0.423000    5.100000    0.078000    0.500000   -1.300000
# 25%      0.191250    0.734750   10.200000    0.177750    4.067047    4.000000
# 50%      0.302500    0.787000   11.923188    0.204000    5.300000    5.400000
# 75%      0.361250    0.848000   14.000000    0.234250    6.700000    7.400000
# max      0.500000    0.948000   21.200000    0.322000   12.400000   15.600000
#
#        G-Lockout  Wins-Lockout  WS-Lockout  VORP-Lockout
# count  20.000000     20.000000   20.000000     20.000000
# mean   53.000000     35.200000    8.145000      3.435000
# std     6.382542      8.003946    2.673156      1.460452
# min    42.000000     25.000000    3.600000      0.700000
# 25%    49.000000     27.750000    6.875000      2.850000
# 50%    50.000000     35.000000    7.700000      3.450000
# 75%    58.500000     40.250000    9.150000      3.875000
# max    66.000000     50.000000   14.500000      7.600000
#
# [8 rows x 25 columns]

# %%
dfc.describe()
# Out:
#            Rank        Age          G  Team Wins  Overall Seed         MP  \
# count  10.00000  10.000000  10.000000  10.000000     10.000000  10.000000
# mean    5.50000  28.300000  73.376855  52.831672      5.400000  34.690000
# std     3.02765   3.683296   8.979960   4.673778      3.306559   1.928413
# min     1.00000  22.000000  59.116279  44.000000      1.000000  31.000000
# 25%     3.25000  26.250000  67.697674  49.479236      3.000000  33.975000
# 50%     5.50000  28.000000  77.093023  53.697674      5.000000  34.950000
# 75%     7.75000  29.750000  80.035714  55.302326      7.750000  35.750000
# max    10.00000  36.000000  82.000000  60.000000     11.000000  37.900000
#
#              PTS        TRB        AST        STL  ...        FT%         WS  \
# count  10.000000  10.000000  10.000000  10.000000  ...  10.000000  10.000000
# mean   26.450000   8.770000   6.600000   1.150000  ...   0.802000  12.236788
# std     4.603199   3.104853   2.913951   0.340751  ...   0.112101   2.800247
# min    14.400000   4.400000   1.300000   0.500000  ...   0.596000   8.581395
# 25%    25.550000   6.700000   5.100000   1.000000  ...   0.714750  10.965116
# 50%    27.600000   8.200000   7.000000   1.200000  ...   0.862500  11.711628
# 75%    29.000000  11.425000   8.425000   1.200000  ...   0.869000  12.766528
# max    30.300000  13.500000  11.100000   1.700000  ...   0.940000  18.938095
#
#            WS/48       VORP        BPM  G-Unadjusted  Wins-Unadjusted  \
# count  10.000000  10.000000  10.000000     10.000000        10.000000
# mean    0.231000   6.554419   7.500000     37.700000        27.200000
# std     0.042311   3.018373   2.652881      4.137901         2.573368
# min     0.181000   3.600000   3.500000     31.000000        22.000000
# 25%     0.202000   4.862791   6.300000     35.500000        25.500000
# 50%     0.218500   5.886656   7.100000     39.000000        27.500000
# 75%     0.245750   6.570930   8.400000     41.000000        29.000000
# max     0.310000  13.200000  11.900000     42.000000        30.000000
#
#        WS-Unadjusted  VORP-Unadjusted  Total Games
# count       10.00000        10.000000    10.000000
# mean         6.29000         3.360000    42.200000
# std          1.40748         1.498295     0.918937
# min          4.50000         1.800000    41.000000
# 25%          5.72500         2.550000    41.250000
# 50%          6.05000         3.050000    42.500000
# 75%          6.57500         3.375000    43.000000
# max          9.70000         6.600000    43.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# # Data Preprocessing

# %%
dfh.isnull().sum() #check the null values
# Out:
# Rank              0
# Player            0
# Age               0
# Tm                0
# Pts Won           0
# Pts Max           0
# Share             0
# G                 0
# Team Wins         0
# Overall Seed      0
# MP                0
# PTS               0
# TRB               0
# AST               0
# STL               0
# BLK               0
# FG%               0
# 3P%               0
# FT%               0
# WS                0
# WS/48             0
# VORP              0
# BPM               0
# G-Lockout       388
# Wins-Lockout    388
# WS-Lockout      388
# VORP-Lockout    388
# dtype: int64

# %%
dfc.isnull().sum() #check the null values
# Out:
# Rank               0
# Player             0
# Age                0
# Tm                 0
# G                  0
# Team Wins          0
# Overall Seed       0
# MP                 0
# PTS                0
# TRB                0
# AST                0
# STL                0
# BLK                0
# FG%                0
# 3P%                0
# FT%                0
# WS                 0
# WS/48              0
# VORP               0
# BPM                0
# G-Unadjusted       0
# Wins-Unadjusted    0
# WS-Unadjusted      0
# VORP-Unadjusted    0
# Total Games        0
# dtype: int64

# %% [markdown]
# The historical_MPVdata.csv contains null values whereas,
# the CurrentMVP.csv contains no null values.

# %%
dfh.columns
# Out:
# Index(['Rank', 'Player', 'Age', 'Tm', 'Pts Won', 'Pts Max', 'Share', 'G',
#        'Team Wins', 'Overall Seed', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK',
#        'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'VORP', 'BPM', 'G-Lockout',
#        'Wins-Lockout', 'WS-Lockout', 'VORP-Lockout'],
#       dtype='object')

# %%
msno.bar(dfh) #graph to display number of null values
# Out:
# <AxesSubplot:>

# %%
msno.bar(dfc) #graph to display number of null values
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Viusalisation

# %%
h = dfh[['G', 'Team Wins', 'Overall Seed', 'MP', 'PTS', 'TRB', 'AST', 'STL','BLK', 'FG%', '3P%','FT%', 'WS', 'WS/48', 'VORP', 'BPM']]
p = plt.figure(figsize=(15, 15))
p.set_facecolor('white')
sns.heatmap(h.corr(), annot = True)
plt.title("Heatmap for Historical_MVPdata.csv Dataset")
# Out:
# Text(0.5, 1.0, 'Heatmap for Historical_MVPdata.csv Dataset')

# %% [markdown]
# # Machine Learning

# %%
# Import the required libraries
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn import neighbors
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold
from scipy.stats import norm
from operator import itemgetter
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing, svm

# %%
train, test = train_test_split(dfh, test_size = 0.25, random_state = 10)

xtrain = train[['3P%', 'STL', 'Overall Seed', 'PTS', 'TRB', 'AST', 'FG%', 'VORP', 'WS']]
ytrain = train[['Share']]

xtest = test[['BLK', 'STL', 'Overall Seed', 'PTS', 'TRB', 'AST', 'FG%', 'VORP', 'WS']]
ytest = test[['Share']]

# %%
def scores(y, model):
    
    model.fit(xtrain, ytrain.values.ravel())
    y_pred = model.predict(xtest)
    
    print("Mean squared error: %.3f" % mean_squared_error(ytest, y_pred))
    print('R2 score: %.3f' % r2_score(ytest, y_pred))

    cvScore = cross_val_score(model, xtest, ytest.values.ravel(), cv = 3, scoring = 'r2')
    print("R2 cross validation score: %0.2f (+/- %0.2f)" % (cvScore.mean(), cvScore.std() * 2))
    
    for i in y_pred:
        y.append(i)

# %%
knn = neighbors.KNeighborsRegressor(n_neighbors = 9, weights = 'uniform')

y_knn = []

scores(y_knn, knn)
# Out:
# Mean squared error: 0.025
# R2 score: 0.713
# R2 cross validation score: 0.63 (+/- 0.01)

# %%
rf = RandomForestRegressor(random_state = 200, n_estimators = 100, criterion = 'mse')

y_rf = []

scores(y_rf, rf)
# Out:
# Mean squared error: 0.035
# R2 score: 0.591
# R2 cross validation score: 0.55 (+/- 0.13)

# %%
rf.feature_importances_
plt.barh(xtrain.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 9 artists>

# %%
regr = LinearRegression()
yp = []
scores(yp,regr)
# Out:
# Mean squared error: 0.135
# R2 score: -0.570
# R2 cross validation score: 0.63 (+/- 0.06)

# %%
dnn = MLPRegressor(
    solver='lbfgs',
    hidden_layer_sizes=100,
    max_iter=10000,
    random_state=10,
    activation='identity',
    learning_rate ='invscaling')

y_dnn = []

scores(y_dnn, dnn)
# Out:
# Mean squared error: 0.134
# R2 score: -0.563
# R2 cross validation score: 0.62 (+/- 0.05)

# %% [markdown]
# # Predictions

# %%
dfCurrentNames = dfc.iloc[:, 1]
dfCurrentPredict = dfc[['BLK', 'STL', 'Overall Seed', 'PTS', 'TRB', 'AST', 'FG%', 'VORP', 'WS']]

dfc.head(10)
# Out:
#    Rank                 Player  Age   Tm          G  Team Wins  Overall Seed  \
# 0     1           Nikola Jokić   26  DEN  82.000000  48.809524             8
# 1     2            Joel Embiid   27  PHI  59.116279  57.209302             1
# 2     3  Giannis Antetokounmpo   26  MIL  80.000000  54.000000             7
# 3     4           James Harden   31  BRK  70.558140  55.302326             3
# 4     5         Damian Lillard   30  POR  80.047619  48.809524             9
# 5     6           LeBron James   36  LAL  78.186047  53.395349             4
# 6     7            Luka Dončić   22  DAL  76.000000  44.000000            11
# 7     8          Kawhi Leonard   29  LAC  66.744186  51.488372             6
# 8     9           Kyrie Irving   28  BRK  59.116279  55.302326             3
# 9    10            Rudy Gobert   28  UTA  82.000000  60.000000             2
#
#      MP   PTS   TRB  ...    FT%         WS  WS/48       VORP   BPM  \
# 0  35.8  27.1  11.2  ...  0.866  18.938095  0.310  10.347619  11.9
# 1  32.6  29.9  11.5  ...  0.859  11.823256  0.294   5.148837   8.6
# 2  34.2  29.0  11.7  ...  0.679  14.200000  0.250  13.200000  11.5
# 3  37.9  25.3   8.0  ...  0.866  11.823256  0.211   5.720930   6.5
# 4  36.0  30.3   4.4  ...  0.940  13.080952  0.217   6.052381   6.3
# 5  33.9  25.4   7.9  ...  0.703  10.869767  0.199   6.483721   7.8
# 6  35.4  29.0   8.4  ...  0.750  10.200000  0.181   6.600000   7.7
# 7  34.5  26.0   6.3  ...  0.870  11.251163  0.233   4.767442   6.3
# 8  35.6  28.1   4.8  ...  0.891   8.581395  0.195   3.623256   4.9
# 9  31.0  14.4  13.5  ...  0.596  11.600000  0.220   3.600000   3.5
#
#    G-Unadjusted  Wins-Unadjusted  WS-Unadjusted  VORP-Unadjusted  Total Games
# 0            42               25            9.7              5.3           42
# 1            31               30            6.2              2.7           43
# 2            40               27            7.1              6.6           41
# 3            37               29            6.2              3.0           43
# 4            41               25            6.7              3.1           42
# 5            41               28            5.7              3.4           43
# 6            38               22            5.1              3.3           41
# 7            35               27            5.9              2.5           43
# 8            31               29            4.5              1.9           43
# 9            41               30            5.8              1.8           41
#
# [10 rows x 25 columns]

# %%
dnnPredict = dnn.predict(dfCurrentPredict)
dnnPredict = dnnPredict.tolist()

for (i, j) in zip(dfCurrentNames, dnnPredict):
    print(i, j)
# Out:
# Nikola Jokić 0.6116954498630897
# Joel Embiid 0.19387420484471166
# Giannis Antetokounmpo 0.3870422798913232
# James Harden 0.3903566333962424
# Damian Lillard 0.4258029684998498
# LeBron James 0.2970377874008344
# Luka Dončić 0.24704255084410823
# Kawhi Leonard 0.1320999634747683
# Kyrie Irving 0.10829607568644897
# Rudy Gobert -0.5703631388901019

# %%
dnnListUnsorted = [[i, j] for i, j in zip(dfCurrentNames, dnnPredict)]
dnnDataUnsorted = [row[1] for row in dnnListUnsorted]
dnnList = sorted(dnnListUnsorted, key = itemgetter(1), reverse = True)

dnnData = [row[1] for row in dnnList]
dnnNames = [row[0] for row in dnnList]
print(dnnList)

x_dnn = np.arange(len(dnnData))
# Out:
# [['Nikola Jokić', 0.6116954498630897], ['Damian Lillard', 0.4258029684998498], ['James Harden', 0.3903566333962424], ['Giannis Antetokounmpo', 0.3870422798913232], ['LeBron James', 0.2970377874008344], ['Luka Dončić', 0.24704255084410823], ['Joel Embiid', 0.19387420484471166], ['Kawhi Leonard', 0.1320999634747683], ['Kyrie Irving', 0.10829607568644897], ['Rudy Gobert', -0.5703631388901019]]

# %%
plt.style.use('fivethirtyeight')

dnn, ax = plt.subplots()

ax.bar(x_dnn, dnnData, width = .7, edgecolor = 'white', color = 'palegreen', linewidth = 4, label = 'Predicted')

labels = dnnNames

rects = ax.patches
for rect, label in zip(rects, labels):
    if rect.get_x() > 8:
        ax.text(rect.get_x() + rect.get_width() / 1.75, rect.get_height() + .02, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
    elif rect.get_x() <= 8:
        height = .03
        ax.text(rect.get_x() + rect.get_width() / 1.75, height, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
        
dnn.suptitle("DNN predicted MVP share", weight = 'bold', size = 18, y = 1.005)
ax.xaxis.set_visible(False)
ax.set_ylabel("Vote Share")

dnn.text(x = -0.02, y = 0.03,
    s = '_______________________________________________________________',
    fontsize = 14, color = 'grey', horizontalalignment='left')
# Out:
# Text(-0.02, 0.03, '_______________________________________________________________')

# %%
rfPredict = rf.predict(dfCurrentPredict)
rfPredict = rfPredict.tolist()

for (i, j) in zip(dfCurrentNames, rfPredict):
    print(i, j)
# Out:
# Nikola Jokić 0.6176200000000002
# Joel Embiid 0.29305
# Giannis Antetokounmpo 0.5775200000000001
# James Harden 0.3867499999999999
# Damian Lillard 0.25817000000000007
# LeBron James 0.2254799999999998
# Luka Dončić 0.22838000000000006
# Kawhi Leonard 0.13924
# Kyrie Irving 0.18030999999999991
# Rudy Gobert 0.37953999999999993

# %%
rfListUnsorted = [[i, j] for i, j in zip(dfCurrentNames, rfPredict)]
rfDataUnsorted = [row[1] for row in rfListUnsorted]
rfList = sorted(rfListUnsorted, key = itemgetter(1), reverse = True)

rfData = [row[1] for row in rfList]
rfNames = [row[0] for row in rfList]
print(rfList)

x_rf = np.arange(len(rfData))
# Out:
# [['Nikola Jokić', 0.6176200000000002], ['Giannis Antetokounmpo', 0.5775200000000001], ['James Harden', 0.3867499999999999], ['Rudy Gobert', 0.37953999999999993], ['Joel Embiid', 0.29305], ['Damian Lillard', 0.25817000000000007], ['Luka Dončić', 0.22838000000000006], ['LeBron James', 0.2254799999999998], ['Kyrie Irving', 0.18030999999999991], ['Kawhi Leonard', 0.13924]]

# %%
plt.style.use('fivethirtyeight')

rf, ax = plt.subplots()

ax.bar(x_rf, rfData, width = .7, edgecolor = 'white', color = 'palegreen', linewidth = 4, label = 'Predicted')

labels = rfNames

rects = ax.patches
for rect, label in zip(rects, labels):
    if rect.get_x() > 6:
        ax.text(rect.get_x() + rect.get_width() / 1.75, rect.get_height() + .02, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
    elif rect.get_x() <= 6:
        height = .03
        ax.text(rect.get_x() + rect.get_width() / 1.75, height, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
        
rf.suptitle("RF predicted MVP share", weight = 'bold', size = 18, y = 1.005)
ax.xaxis.set_visible(False)
ax.set_ylabel("Vote Share")

rf.text(x = -0.02, y = 0.03,
    s = '_______________________________________________________________',
    fontsize = 14, color = 'grey', horizontalalignment='left')
# Out:
# Text(-0.02, 0.03, '_______________________________________________________________')

# %%
knnPredict = knn.predict(dfCurrentPredict)
knnPredict = knnPredict.tolist()

for (i, j) in zip(dfCurrentNames, knnPredict):
    print(i, j)
# Out:
# Nikola Jokić 0.4945555555555555
# Joel Embiid 0.49877777777777776
# Giannis Antetokounmpo 0.5055555555555555
# James Harden 0.41144444444444445
# Damian Lillard 0.20900000000000002
# LeBron James 0.21433333333333335
# Luka Dončić 0.17066666666666666
# Kawhi Leonard 0.12166666666666666
# Kyrie Irving 0.1771111111111111
# Rudy Gobert 0.08211111111111111

# %%
knnListUnsorted = [[i, j] for i, j in zip(dfCurrentNames, knnPredict)]
knnDataUnsorted = [row[1] for row in knnListUnsorted]
knnList = sorted(knnListUnsorted, key = itemgetter(1), reverse = True)

knnData = [row[1] for row in knnList]
knnNames = [row[0] for row in knnList]
print(knnList)

x_knn = np.arange(len(knnData))
# Out:
# [['Giannis Antetokounmpo', 0.5055555555555555], ['Joel Embiid', 0.49877777777777776], ['Nikola Jokić', 0.4945555555555555], ['James Harden', 0.41144444444444445], ['LeBron James', 0.21433333333333335], ['Damian Lillard', 0.20900000000000002], ['Kyrie Irving', 0.1771111111111111], ['Luka Dončić', 0.17066666666666666], ['Kawhi Leonard', 0.12166666666666666], ['Rudy Gobert', 0.08211111111111111]]

# %%
plt.style.use('fivethirtyeight')

knn, ax = plt.subplots()

ax.bar(x_knn, knnData, width = .7, edgecolor = 'white', color = 'palegreen', linewidth = 4, label = 'Predicted')

labels = knnNames

rects = ax.patches
for rect, label in zip(rects, labels):
    if rect.get_x() > 5:
        ax.text(rect.get_x() + rect.get_width() / 1.75, rect.get_height() + .02, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
    elif rect.get_x() <= 5:
        height = .03
        ax.text(rect.get_x() + rect.get_width() / 1.75, height, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
        
knn.suptitle("KNN predicted MVP share", weight = 'bold', size = 18, y = 1.005)
ax.xaxis.set_visible(False)
ax.set_ylabel("Vote Share")

knn.text(x = -0.02, y = 0.03,
    s = '_______________________________________________________________',
    fontsize = 14, color = 'grey', horizontalalignment='left')
# Out:
# Text(-0.02, 0.03, '_______________________________________________________________')

# %%
avgPredict = []

for (i, j, h) in zip(rfDataUnsorted, knnDataUnsorted, dnnDataUnsorted):
    avgPredict.append((i + j + h) / 3)

avgList = [[i, j] for i, j in zip(dfCurrentNames, avgPredict)]
avgList = sorted(avgList, key = itemgetter(1), reverse = True)

avgData = [row[1] for row in avgList]
avgNames = [row[0] for row in avgList]
print(avgList)

x_avg = np.arange(len(avgData))
# Out:
# [['Nikola Jokić', 0.5746236684728818], ['Giannis Antetokounmpo', 0.49003927848229295], ['James Harden', 0.39618369261356223], ['Joel Embiid', 0.3285673275408298], ['Damian Lillard', 0.2976576561666166], ['LeBron James', 0.24561704024472253], ['Luka Dončić', 0.21536307250359166], ['Kyrie Irving', 0.15523906226585335], ['Kawhi Leonard', 0.131002210047145], ['Rudy Gobert', -0.03623734259299697]]

# %%
plt.style.use('fivethirtyeight')

avg, ax = plt.subplots()

ax.bar(x_avg, avgData, width = .7, edgecolor = 'white', color = 'palegreen', linewidth = 4, label = 'Predicted')

labels = avgNames

rects = ax.patches
for rect, label in zip(rects, labels):
    if rect.get_x() > 6:
        ax.text(rect.get_x() + rect.get_width() / 1.75, rect.get_height() + .02, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
    elif rect.get_x() <= 6:
        height = .03
        ax.text(rect.get_x() + rect.get_width() / 1.75, height, label,
        ha='center', va='bottom', rotation = 'vertical', color = 'black')
        
avg.suptitle("Average predicted MVP share", weight = 'bold', size = 18, y = 1.005)
ax.xaxis.set_visible(False)
ax.set_ylabel("Vote Share")

avg.text(x = -0.02, y = 0.03,
    s = '_______________________________________________________________',
    fontsize = 14, color = 'grey', horizontalalignment='left')
# Out:
# Text(-0.02, 0.03, '_______________________________________________________________')
